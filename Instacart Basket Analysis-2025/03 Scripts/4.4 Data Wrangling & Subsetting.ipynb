# %%
#importing libraries
import pandas as pd
import numpy as np
import os

# %%
#generating a path 
path = r'/Users/samarjitgehdu/Documents/Python/Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/samarjitgehdu/Documents/Python/Instacart Basket Analysis'

# %%
#importing data
df_ords =  pd.read_csv(os.path.join(path, "02 Data", "Original Data", "orders.csv"), index_col = False)
df_prods =  pd.read_csv(os.path.join(path, "02 Data", "Original Data", "products.csv"), index_col = False)
df_dep =  pd.read_csv(os.path.join(path, "02 Data", "Original Data", "departments.csv"), index_col = False)

# %%
#Dropping eval_est column from orders.csv 
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
#changing datatype for order ID in the orders data frame
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
#Transposing df_dep
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Making first row of df_dep_t for the header
new_header = df_dep_t.iloc[0]

# %%
# copying df_dep_t from first row in df_dep_t_new
df_dep_t_new = df_dep_t[1:]

# %%
#Making ther header row ad the data frame header
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#Creating Data Dictionary
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
#Step 2: Order number can be changed to string as we don't need stats for it
df_ords['order_number'] = df_ords['order_number'].astype('str')

# %%
df_ords.describe()
# Out:
#             user_id     order_dow  order_hour_of_day  days_since_prior_order
# count  3.421083e+06  3.421083e+06       3.421083e+06            3.214874e+06
# mean   1.029782e+05  2.776219e+00       1.345202e+01            1.111484e+01
# std    5.953372e+04  2.046829e+00       4.226088e+00            9.206737e+00
# min    1.000000e+00  0.000000e+00       0.000000e+00            0.000000e+00
# 25%    5.139400e+04  1.000000e+00       1.000000e+01            4.000000e+00
# 50%    1.026890e+05  3.000000e+00       1.300000e+01            7.000000e+00
# 75%    1.543850e+05  5.000000e+00       1.600000e+01            1.500000e+01
# max    2.062090e+05  6.000000e+00       2.300000e+01            3.000000e+01

# %%
#Step 3: Rename column
df_ords.rename(columns = {"order_dow" : "orders_day_of_week"}, inplace = True)

# %%
df_ords.head()
# Out:
#   order_id  user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329        1            1                   2                  8
# 1  2398795        1            2                   3                  7
# 2   473747        1            3                   3                 12
# 3  2254736        1            4                   4                  7
# 4   431534        1            5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Step 4:vFinding the busiest Hour
df_ords['order_hour_of_day'].value_counts(dropna = True)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# The busiest hour of the day is 10am

# %%
#Step 5: WHat "4" means in the data dictionary
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# Department is 4 = produce

# %%
#Step 6: Creating a subset for breakfast time
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# Breakfast is numner 14 in the department list

# %%
#creating a subset
df_prods_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
#Results
df_prods_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %%
#Step7: creating 'dinner party' subset
df_prods_dinner_party = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %% [markdown]
# Alcohol, deli, beverages, and meat/seafood is at positions 5,7,12,20 respectively

# %%
#Step8: Number of Rows Generated.
df_prods_dinner_party.shape
# Out:
# (7650, 5)

# %%
#Step 9: finding info about customer with user_id 1
df_user_id = df_ords.loc[df_ords['user_id'] == '1']
df_user_id
# Out:
#    order_id user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1            1                   2                  8
# 1   2398795       1            2                   3                  7
# 2    473747       1            3                   3                 12
# 3   2254736       1            4                   4                  7
# 4    431534       1            5                   4                 15
# 5   3367565       1            6                   2                  7
# 6    550135       1            7                   1                  9
# 7   3108588       1            8                   1                 14
# 8   2295261       1            9                   1                 16
# 9   2550362       1           10                   4                  8
# 10  1187899       1           11                   4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %%
df_user_id.describe()
# Out:
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count           11.000000          11.000000               10.000000
# mean             2.636364          10.090909               19.000000
# std              1.286291           3.477198                9.030811
# min              1.000000           7.000000                0.000000
# 25%              1.500000           7.500000               14.250000
# 50%              3.000000           8.000000               19.500000
# 75%              4.000000          13.000000               26.250000
# max              4.000000          16.000000               30.000000

# %% [markdown]
# Observations:
#
# The individual with this user id only orders from Sunday to Wednesday; Mostly the orders are places before 8am. Average placement of order is 19 day and the user never spends more than 30 days.

# %%
#Exporting the data frame
df_ords.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'))

# %%
#Exporting the Department data frame
df_dep_t_new.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'departments_wrangled.csv'))

# %% [markdown]
# End of the code
